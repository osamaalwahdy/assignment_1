# %%
import time
from datetime import datetime

def log(stage, msg):
    timestamp = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S UTC")
    print(f"[{timestamp}] [{stage}] {msg}")

def iot_device_lifecycle():
    log("Stage 1", "Threat model created. Potential threats identified: unauthorized access, data tampering, network attacks.")
    time.sleep(1)

    log("Stage 2", "Secure boot initialized. Bootloader verified and device integrity checked.")
    time.sleep(1)

    mock_keys = {"device_key": "ABC123XYZ", "server_key": "SERVER456"}
    log("Stage 3", f"Keys injected securely: {mock_keys}")
    time.sleep(1)

    log("Stage 4", "OTA firmware update checked. Latest firmware verified and applied successfully.")
    time.sleep(1)

    log("Stage 5", "Device decommissioned. All secrets wiped and keys removed securely.")
    time.sleep(1)

iot_device_lifecycle()
# Out:
# /tmp/ipython-input-2625196567.py:5: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S UTC")
# [2025-11-25 14:52:57 UTC] [Stage 1] Threat model created. Potential threats identified: unauthorized access, data tampering, network attacks.
# [2025-11-25 14:52:58 UTC] [Stage 2] Secure boot initialized. Bootloader verified and device integrity checked.
# [2025-11-25 14:52:59 UTC] [Stage 3] Keys injected securely: {'device_key': 'ABC123XYZ', 'server_key': 'SERVER456'}
# [2025-11-25 14:53:00 UTC] [Stage 4] OTA firmware update checked. Latest firmware verified and applied successfully.
# [2025-11-25 14:53:01 UTC] [Stage 5] Device decommissioned. All secrets wiped and keys removed securely.
